# %% [markdown]
# # Setup

# %%
import numpy as np
import keras
from keras import layers

# %% [markdown]
# # Prepare the data

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32")/255
x_test = x_test.astype("float32")/255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # Build the model

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_5 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_6 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 1600)              0
#
#  dropout_2 (Dropout)         (None, 1600)              0
#
#  dense_2 (Dense)             (None, 10)                16010
#
# =================================================================
# Total params: 34826 (136.04 KB)
# Trainable params: 34826 (136.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Train the model

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 3s 4ms/step - loss: 0.3635 - accuracy: 0.8912 - val_loss: 0.0838 - val_accuracy: 0.9783
# Epoch 2/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1107 - accuracy: 0.9660 - val_loss: 0.0587 - val_accuracy: 0.9838
# Epoch 3/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0837 - accuracy: 0.9744 - val_loss: 0.0474 - val_accuracy: 0.9868
# Epoch 4/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0711 - accuracy: 0.9779 - val_loss: 0.0404 - val_accuracy: 0.9890
# Epoch 5/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0619 - accuracy: 0.9806 - val_loss: 0.0380 - val_accuracy: 0.9903
# Epoch 6/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0566 - accuracy: 0.9827 - val_loss: 0.0363 - val_accuracy: 0.9917
# Epoch 7/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0526 - accuracy: 0.9837 - val_loss: 0.0331 - val_accuracy: 0.9918
# Epoch 8/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0484 - accuracy: 0.9846 - val_loss: 0.0351 - val_accuracy: 0.9907
# Epoch 9/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0442 - accuracy: 0.9859 - val_loss: 0.0313 - val_accuracy: 0.9913
# Epoch 10/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0413 - accuracy: 0.9864 - val_loss: 0.0316 - val_accuracy: 0.9925
# Epoch 11/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0394 - accuracy: 0.9876 - val_loss: 0.0307 - val_accuracy: 0.9925
# Epoch 12/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0386 - accuracy: 0.9876 - val_loss: 0.0313 - val_accuracy: 0.9917
# Epoch 13/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0349 - accuracy: 0.9886 - val_loss: 0.0309 - val_accuracy: 0.9918
# Epoch 14/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0339 - accuracy: 0.9885 - val_loss: 0.0288 - val_accuracy: 0.9923
# Epoch 15/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0326 - accuracy: 0.9892 - val_loss: 0.0271 - val_accuracy: 0.9923

# %% [markdown]
# # Evaluate the trained model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.024022288620471954
# Test accuracy: 0.9912999868392944
